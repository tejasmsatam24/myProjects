# %% [markdown]
# # Assignment04 - Jupyter, R and Plotting
#
# This is based on *Data Visualization in R with ggplot2* from lynda.com
#
# ## Introducing ggplot2

# %% [markdown]
# <span style="color:red">1. Install packages `tidyverse` and `ggmap`</span>

# %%
install.packages('tidyverse', repos='http://cran.us.r-project.org')
install.packages('ggmap', repos='http://cran.us.r-project.org')
# Out:
# package 'tidyverse' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\ts848\AppData\Local\Temp\Rtmpq0VbQ6\downloaded_packages
# package 'ggmap' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\ts848\AppData\Local\Temp\Rtmpq0VbQ6\downloaded_packages

# %% [markdown]
# <span style="color:red">2. Load the `tidyverse` library.</span>

# %%
library(tidyverse)
# Out:
# Warning message:
# "package 'tidyverse' was built under R version 3.5.2"-- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.1.0     v purrr   0.2.5
# v tibble  1.4.2     v dplyr   0.7.6
# v tidyr   0.8.1     v stringr 1.3.1
# v readr   1.1.1     v forcats 0.3.0
# Warning message:
# "package 'ggplot2' was built under R version 3.5.2"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %% [markdown]
# <span style="color:red">3. Load the dataset *college.csv* from the Data directory included within your repository and display the top of the file using the `head` function.</span>

# %%
college <- read.csv(file = 'Data/college.csv')
college
# Out:
#      id     name                                               city
# 1    102669 Alaska Pacific University                          Anchorage
# 2    101648 Marion Military Institute                          Marion
# 3    100830 Auburn University at Montgomery                    Montgomery
# 4    101879 University of North Alabama                        Florence
# 5    100858 Auburn University                                  Auburn
# 6    100663 University of Alabama at Birmingham                Birmingham
# 7    101480 Jacksonville State University                      Jacksonville
# 8    102049 Samford University                                 Birmingham
# 9    101709 University of Montevallo                           Montevallo
# 10   100751 The University of Alabama                          Tuscaloosa
# 11   102261 Southeastern Bible College                         Birmingham
# 12   100706 University of Alabama in Huntsville                Huntsville
# 13   101587 University of West Alabama                         Livingston
# 14   102094 University of South Alabama                        Mobile
# 15   102368 Troy University                                    Troy
# 16   101435 Huntingdon College                                 Montgomery
# 17   101693 University of Mobile                               Mobile
# 18   102234 Spring Hill College                                Mobile
# 19   100937 Birmingham Southern College                        Birmingham
# 20   101912 Oakwood University                                 Huntsville
# 21   101073 Concordia College Alabama                          Selma
# 22   100724 Alabama State University                           Montgomery
# 23   102377 Tuskegee University                                Tuskegee
# 24   100654 Alabama A & M University                           Normal
# 25   102270 Stillman College                                   Tuscaloosa
# 26   107585 University of Arkansas Community College-Morrilton Morrilton
# 27   107983 Southern Arkansas University Main Campus           Magnolia
# 28   106467 Arkansas Tech University                           Russellville
# 29   107877 Williams Baptist College                           Walnut Ridge
# 30   106458 Arkansas State University-Main Campus              Jonesboro
# ...  ...    ...                                                ...
# 1240 238430 Cardinal Stritch University                        Milwaukee
# 1241 239512 Northland College                                  Ashland
# 1242 240107 Viterbo University                                 La Crosse
# 1243 239628 Ripon College                                      Ripon
# 1244 238458 Carroll University                                 Waukesha
# 1245 239716 Saint Norbert College                              De Pere
# 1246 238476 Carthage College                                   Kenosha
# 1247 239318 Milwaukee School of Engineering                    Milwaukee
# 1248 239105 Marquette University                               Milwaukee
# 1249 239390 Mount Mary University                              Milwaukee
# 1250 238193 Alverno College                                    Milwaukee
# 1251 237136 Appalachian Bible College                          Mount Hope
# 1252 237215 Bluefield State College                            Bluefield
# 1253 237330 Concord University                                 Athens
# 1254 237312 University of Charleston                           Charleston
# 1255 237792 Shepherd University                                Shepherdstown
# 1256 237367 Fairmont State University                          Fairmont
# 1257 237525 Marshall University                                Huntington
# 1258 237640 Ohio Valley University                             Vienna
# 1259 237899 West Virginia State University                     Institute
# 1260 237358 Davis & Elkins College                             Elkins
# 1261 237950 West Virginia University Institute of Technology   Montgomery
# 1262 238032 West Virginia University                           Morgantown
# 1263 237932 West Liberty University                            West Liberty
# 1264 237969 West Virginia Wesleyan College                     Buckhannon
# 1265 237385 Glenville State College                            Glenville
# 1266 237118 Alderson Broaddus University                       Philippi
# 1267 238078 Wheeling Jesuit University                         Wheeling
# 1268 237181 Bethany College                                    Bethany
# 1269 240727 University of Wyoming                              Laramie
#      state region  highest_degree control gender admission_rate sat_avg
# 1    AK    West    Graduate       Private CoEd   0.4207         1054
# 2    AL    South   Associate      Public  CoEd   0.6139         1055
# 3    AL    South   Graduate       Public  CoEd   0.8017         1009
# 4    AL    South   Graduate       Public  CoEd   0.6788         1029
# 5    AL    South   Graduate       Public  CoEd   0.8347         1215
# 6    AL    South   Graduate       Public  CoEd   0.8569         1107
# 7    AL    South   Graduate       Public  CoEd   0.8326         1041
# 8    AL    South   Graduate       Private CoEd   0.5954         1165
# 9    AL    South   Graduate       Public  CoEd   0.7430         1070
# 10   AL    South   Graduate       Public  CoEd   0.5105         1185
# 11   AL    South   Bachelor       Private CoEd   1.0000          930
# 12   AL    South   Graduate       Public  CoEd   0.8203         1219
# 13   AL    South   Graduate       Public  CoEd   0.7199          990
# 14   AL    South   Graduate       Public  CoEd   0.8335         1048
# 15   AL    South   Graduate       Public  CoEd   0.4414         1050
# 16   AL    South   Bachelor       Private CoEd   0.5839         1026
# 17   AL    South   Graduate       Private CoEd   0.5847         1014
# 18   AL    South   Graduate       Private CoEd   0.5177         1116
# 19   AL    South   Bachelor       Private CoEd   0.5339         1181
# 20   AL    South   Graduate       Private CoEd   0.4787          928
# 21   AL    South   Bachelor       Private CoEd   0.5328          942
# 22   AL    South   Graduate       Public  CoEd   0.5326          851
# 23   AL    South   Graduate       Private CoEd   0.4922          978
# 24   AL    South   Graduate       Public  CoEd   0.5256          827
# 25   AL    South   Bachelor       Private CoEd   0.5901          811
# 26   AR    South   Associate      Public  CoEd   0.6181          930
# 27   AR    South   Graduate       Public  CoEd   0.7142          989
# 28   AR    South   Graduate       Public  CoEd   0.8626         1010
# 29   AR    South   Bachelor       Private CoEd   0.7049          983
# 30   AR    South   Graduate       Public  CoEd   0.7239         1088
# ...  ...   ...     ...            ...     ...    ...            ...
# 1240 WI    Midwest Graduate       Private CoEd   0.8298         1003
# 1257  -82.44515 38.41925
# 1258  -81.54846 39.32702
# 1259  -81.76580 38.38377
# 1260  -79.84673 38.92594
# 1261  -81.32845 38.18038
# 1262  -79.95590 39.62953
# 1263  -80.59369 40.16979
# 1264  -80.23203 38.99399
# 1265  -80.83760 38.93426
# 1266  -80.04036 39.15232
# 1267  -80.72091 40.06396
# 1268  -80.55674 40.20563
# 1269 -105.59110 41.31137

# %% [markdown]
# <span style="color:red">4. Using the R `summary` function, to produce a summary of the dataset.</span>

# %%
summary(college)
# Out:
#        id                          name                city          state
#  Min.   :100654   Westminster College:   3   New York    :  15   PA     :101
#  1st Qu.:153250   Anderson University:   2   Boston      :  11   NY     : 84
#  Median :186283   Aquinas College    :   2   Chicago     :  10   CA     : 71
#  Mean   :186988   Bethany College    :   2   Philadelphia:   9   TX     : 63
#  3rd Qu.:215284   Bethel University  :   2   Cleveland   :   8   OH     : 52
#  Max.   :484905   Emmanuel College   :   2   Los Angeles :   8   IL     : 47
#                   (Other)            :1256   (Other)     :1208   (Other):851
#        region      highest_degree    control      gender     admission_rate
#  Midwest  :353   Associate:  20   Private:763   CoEd :1237   Min.   :0.0509
#  Northeast:299   Bachelor : 200   Public :506   Men  :   4   1st Qu.:0.5339
#  South    :459   Graduate :1049                 Women:  28   Median :0.6687
#  West     :158                                               Mean   :0.6501
#                                                              3rd Qu.:0.7859
#                                                              Max.   :1.0000
#
#     sat_avg       undergrads       tuition      faculty_salary_avg
#  Min.   : 720   Min.   :   47   Min.   : 2732   Min.   : 1451
#  1st Qu.: 973   1st Qu.: 1296   1st Qu.: 8970   1st Qu.: 6191
#  Median :1040   Median : 2556   Median :20000   Median : 7272
#  Mean   :1060   Mean   : 5629   Mean   :21025   Mean   : 7656
#  3rd Qu.:1120   3rd Qu.: 6715   3rd Qu.:30364   3rd Qu.: 8671
#  Max.   :1545   Max.   :52280   Max.   :51008   Max.   :20650
#
#  loan_default_rate  median_debt         lon               lat
#  0.057  :  32      Min.   : 6056   Min.   :-157.92   Min.   :19.71
#  0.04   :  23      1st Qu.:21250   1st Qu.: -94.17   1st Qu.:35.22
#  0.046  :  22      Median :24589   Median : -84.89   Median :39.74
#  0.027  :  21      Mean   :23483   Mean   : -88.29   Mean   :38.61
#  0.035  :  19      3rd Qu.:27000   3rd Qu.: -78.63   3rd Qu.:41.81
#  0.038  :  19      Max.   :41000   Max.   : -68.59   Max.   :61.22
#  (Other):1133

# %% [markdown]
# <span style="color:red">5. What is a factor in R, write your answer in the cell below. (*You will need to make sure the cell has been changed to a markdown cell.*)</span>

# %% [markdown]
# Factors are used to represent categorical data. They are used for statistical modelling. let us understand them by using example,
#
# food <- factor(c("low", "high", "medium", "high", "low", "medium", "high"))
# levels(food)
#
# now here the factor will differentiate and will give us the individual element
# so the output will be
# "high"   "low"    "medium"

# %% [markdown]
# <span style="color:red">6. Use the R `mutate` function to convert the columns state, region, highest_degree, control, gender to a factor variable, `mutate` loan_default to a numeric value rerun the `summary` function.</span>

# %%
college <- college %>%
mutate(state = as.factor(state), region = as.factor(region), highest_degree = as.factor(highest_degree), control = as.factor(control), gender = as.factor(gender))
summary(college)
# Out:
#        id                          name                city          state
#  Min.   :100654   Westminster College:   3   New York    :  15   PA     :101
#  1st Qu.:153250   Anderson University:   2   Boston      :  11   NY     : 84
#  Median :186283   Aquinas College    :   2   Chicago     :  10   CA     : 71
#  Mean   :186988   Bethany College    :   2   Philadelphia:   9   TX     : 63
#  3rd Qu.:215284   Bethel University  :   2   Cleveland   :   8   OH     : 52
#  Max.   :484905   Emmanuel College   :   2   Los Angeles :   8   IL     : 47
#                   (Other)            :1256   (Other)     :1208   (Other):851
#        region      highest_degree    control      gender     admission_rate
#  Midwest  :353   Associate:  20   Private:763   CoEd :1237   Min.   :0.0509
#  Northeast:299   Bachelor : 200   Public :506   Men  :   4   1st Qu.:0.5339
#  South    :459   Graduate :1049                 Women:  28   Median :0.6687
#  West     :158                                               Mean   :0.6501
#                                                              3rd Qu.:0.7859
#                                                              Max.   :1.0000
#
#     sat_avg       undergrads       tuition      faculty_salary_avg
#  Min.   : 720   Min.   :   47   Min.   : 2732   Min.   : 1451
#  1st Qu.: 973   1st Qu.: 1296   1st Qu.: 8970   1st Qu.: 6191
#  Median :1040   Median : 2556   Median :20000   Median : 7272
#  Mean   :1060   Mean   : 5629   Mean   :21025   Mean   : 7656
#  3rd Qu.:1120   3rd Qu.: 6715   3rd Qu.:30364   3rd Qu.: 8671
#  Max.   :1545   Max.   :52280   Max.   :51008   Max.   :20650
#
#  loan_default_rate  median_debt         lon               lat
#  0.057  :  32      Min.   : 6056   Min.   :-157.92   Min.   :19.71
#  0.04   :  23      1st Qu.:21250   1st Qu.: -94.17   1st Qu.:35.22
#  0.046  :  22      Median :24589   Median : -84.89   Median :39.74
#  0.027  :  21      Mean   :23483   Mean   : -88.29   Mean   :38.61
#  0.035  :  19      3rd Qu.:27000   3rd Qu.: -78.63   3rd Qu.:41.81
#  0.038  :  19      Max.   :41000   Max.   : -68.59   Max.   :61.22
#  (Other):1133

# %%
college <- college %>%
mutate(loan_default_rate=as.numeric(loan_default_rate))
summary(college)
# Out:
#        id                          name                city          state
#  Min.   :100654   Westminster College:   3   New York    :  15   PA     :101
#  1st Qu.:153250   Anderson University:   2   Boston      :  11   NY     : 84
#  Median :186283   Aquinas College    :   2   Chicago     :  10   CA     : 71
#  Mean   :186988   Bethany College    :   2   Philadelphia:   9   TX     : 63
#  3rd Qu.:215284   Bethel University  :   2   Cleveland   :   8   OH     : 52
#  Max.   :484905   Emmanuel College   :   2   Los Angeles :   8   IL     : 47
#                   (Other)            :1256   (Other)     :1208   (Other):851
#        region      highest_degree    control      gender     admission_rate
#  Midwest  :353   Associate:  20   Private:763   CoEd :1237   Min.   :0.0509
#  Northeast:299   Bachelor : 200   Public :506   Men  :   4   1st Qu.:0.5339
#  South    :459   Graduate :1049                 Women:  28   Median :0.6687
#  West     :158                                               Mean   :0.6501
#                                                              3rd Qu.:0.7859
#                                                              Max.   :1.0000
#
#     sat_avg       undergrads       tuition      faculty_salary_avg
#  Min.   : 720   Min.   :   47   Min.   : 2732   Min.   : 1451
#  1st Qu.: 973   1st Qu.: 1296   1st Qu.: 8970   1st Qu.: 6191
#  Median :1040   Median : 2556   Median :20000   Median : 7272
#  Mean   :1060   Mean   : 5629   Mean   :21025   Mean   : 7656
#  3rd Qu.:1120   3rd Qu.: 6715   3rd Qu.:30364   3rd Qu.: 8671
#  Max.   :1545   Max.   :52280   Max.   :51008   Max.   :20650
#
#  loan_default_rate  median_debt         lon               lat
#  Min.   :  1.00    Min.   : 6056   Min.   :-157.92   Min.   :19.71
#  1st Qu.: 35.00    1st Qu.:21250   1st Qu.: -94.17   1st Qu.:35.22
#  Median : 55.00    Median :24589   Median : -84.89   Median :39.74
#  Mean   : 64.18    Mean   :23483   Mean   : -88.29   Mean   :38.61
#  3rd Qu.: 83.00    3rd Qu.:27000   3rd Qu.: -78.63   3rd Qu.:41.81
#  Max.   :198.00    Max.   :41000   Max.   : -68.59   Max.   :61.22

# %% [markdown]
# ## Geometry Types and Aesthetics

# %% [markdown]
# <span style="color:red">7. Produce a scatterplot using the R function `ggplot` to produce a scatterplot where the *tuition* variable is plotted on x axis, *sat_avg* variable is plotted on y axis, color the marks by the *control* variable, and set the size to be determined by *undergrads* variable; address the overplotting of points by varying the alpha value until the plot looks good to you.</span>

# %%
ggplot(data=college) +
geom_point(mapping=aes(x=tuition,y=sat_avg,color=control,size=undergrads),alpha=60/100)
# Out:
# plot without title

# %% [markdown]
# <span style="color:red">8. Plot a fitted line over the plot from question 6. using the loess method, remove the standard error aesthetic that the `geom_smooth` function adds by default, adjust the transpancncy of points to maximize readability of your final plot.

# %%
ggplot(data=college,mapping=aes(x=tuition,y=sat_avg,color=control,size=undergrads),alpha=60/100) +
geom_smooth(se=FALSE)
geom_point(alpha=1/25)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# geom_point: na.rm = FALSE
# stat_identity: na.rm = FALSE
# position_identity
# plot without title

# %% [markdown]
# <span style="color:red">9. Produce a bar chart showing the breakdown by region of public and private schools.

# %%
ggplot(data=college) +
geom_bar(mapping=aes(x=region,fill=control))
# Out:
# plot without title

# %% [markdown]
# <span style="color:red">10. Produce a new bar chart comparing the average tuition for each region.</span>

# %%
college %>%
group_by(region) %>%
summarize(average_tuition=mean(tuition))%>%
ggplot() +
geom_col(mapping=aes(x=region,y=average_tuition))
# Out:
# plot without title

# %% [markdown]
# <span style="color:red">11. Produce a histogram that summarizes undergraduate populations for all colleges with the origin starting at zero.</span>

# %%
ggplot(data=college) +
geom_histogram(mapping=aes(x= undergrads),origin=0)
# Out:
# Warning message:
# "`origin` is deprecated. Please use `boundary` instead."`stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# <span style="color:red">12. Produce a new histogram that summarizes undergraduate populations for all colleges with the origin starting at zero and the width of bins is set to 5000.</span>

# %%
ggplot(data=college) +
geom_histogram(mapping=aes(x= undergrads),origin=0,binwidth=5000)
# Out:
# Warning message:
# "`origin` is deprecated. Please use `boundary` instead."
# plot without title

# %% [markdown]
# <span style="color:red">13. Redraw your histogram from step 10, where the width of the plot is twice the height.</span>

# %%
ggplot(data=college) +
geom_histogram(mapping=aes(x= undergrads),origin=0,width=2*height)
# Out:
# Error in layer(data = data, mapping = mapping, stat = stat, geom = GeomBar, : object 'height' not found
# Traceback:
#
# 1. geom_histogram(mapping = aes(x = undergrads), origin = 0, width = 2 *
#  .     height)
# 2. layer(data = data, mapping = mapping, stat = stat, geom = GeomBar,
#  .     position = position, show.legend = show.legend, inherit.aes = inherit.aes,
#  .     params = list(binwidth = binwidth, bins = bins, na.rm = na.rm,
#  .         pad = FALSE, ...))

# %% [markdown]
# <span style="color:red">14. Produce a graph using the ggplot geometry function `geom_jitter`, plotting the institutional type (*control* variable) versus cost (*tuition* variable) and coloring the marks by the average SAT score (*sat_avg* variable).</span>

# %%
ggplot(data=college) +
geom_jitter(mapping=aes(x=control,y=tuition,color=sat_avg))
# Out:
# plot without title

# %% [markdown]
# <span style="color:red">15. Create a box plot of tuition and institution type.</span>

# %%
ggplot(data=college) +
geom_boxplot(mapping=aes(x=control,y=tuition))
# Out:
# plot without title

# %% [markdown]
# <span style="color:red">16. Create a final visualization with the following constraints/guidelines:<br/></span>
# <span style="color:red">- Title: *Number of Schools in Different Regions of the United States*<br/></span>
# <span style="color:red">- Subtitle: *Source: U.S. Department of Education*<br/></span>
# <span style="color:red">- Graph should have a blank background for panel<br/></span>
# <span style="color:red">- Graph should have a blank background for plot<br/></span>
# <span style="color:red">- X Axis Label: Region<br/></span>
# <span style="color:red">- Y Axis Label: Number of Schools<br/></span>
# <span style="color:red">- Legend Label: Institution Type<br/></span>
# <span style="color:red">- Fill Colors: *Red* for private schools and *Black* for public schools<br/></span>
# <span style="color:red">- Legend Location: bottom of graph with items all on one line and a keywidth of 2.5<br/></span>
# <span style="color:red">- Range for Y axis: 0 to 500</span>

# %%
ggplot(data=college) +
geom_bar(mapping=aes(x=region,fill=control)) +
theme(panel.background=element_blank(),plot.background=element_blank()) +
ylab("Number of Schools") +
xlab("Region") +
ylim(0,500) +
scale_fill_manual(values=c("red","black"),guide=guide_legend(title="Institution Type",nrow=1,label.position="bottom",keywidth=2.5)) +
theme(legend.position="bottom") +
ggtitle("Number of Schools in Different Regions of the United States",subtitle="Source: U.S. Department of Education")
# Out:
# plot without title

# %% [markdown]
# <span style="color:red">17. Create a map of colleges in Illinois, showing the difference in institutional type and relative size of undergraduate populations. Consider this a final visualization with appropriate labels and legends.</span>

# %% [markdown]
# ## Optional Exercises - Very Helpful for Upcoming Projects

# %% [markdown]
# <span style="color:red">18. Obtain a personenl Goggle Map API key. Setup your R environment to use the new key. You DO NOT need to install devtools but you do need to register for your own key.</span>

# %%
library(ggmap)
register_google(key="AIzaSyAyioXNK9gdwwXfwYH1FZSA-aDxdpqkwo4")

# %% [markdown]
# <span style="color:red">19. Use qmap to plot a map of *DeKalb, IL* at a zoom factor of 12.</span>

# %%
qmap("DeKalb, IL",zoom=12)
# Out:
# Source : https://maps.googleapis.com/maps/api/staticmap?center=DeKalb,%20IL&zoom=12&size=640x640&scale=2&maptype=terrain&language=en-EN&key=xxx-aDxdpqkwo4
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=DeKalb,+IL&key=xxx-aDxdpqkwo4
# plot without title

# %% [markdown]
# <span style="color:red">20. Get a map of *DeKalb, IL* at a zoom factor of 15 and plot using the `ggmap` function.</span>

# %%
library(ggmap)
register_google(key="AIzaSyB-dR-wCtEsgGsLLjRM-PeQhnbU8yZLzCQ")
dekalb_map <- get_map("DeKalb,IL",zoom=15)
ggmap(dekalb_map)
# Out:
# Source : https://maps.googleapis.com/maps/api/staticmap?center=DeKalb,IL&zoom=15&size=640x640&scale=2&maptype=terrain&language=en-EN&key=xxx-dR-wCtEsgGsLLjRM-PeQhnbU8yZLzCQ
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=DeKalb,IL&key=xxx-dR-wCtEsgGsLLjRM-PeQhnbU8yZLzCQ
# plot without title

# %% [markdown]
# <span style="color:red">21. Using the `geocode` function, get latitude and longitude for *DeKalb, IL*, get second latitude and longitude for the *Egyptian Theatre in DeKalb, Illinois*, display the results.</span>

# %%
dekalb <- geocode("DeKalb, IL")
dekalb
dekalbtheatre <- geocode("Egyptian Theatre in DeKalb, Illinois")
dekalbtheatre
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=DeKalb,+IL&key=xxx-dR-wCtEsgGsLLjRM-PeQhnbU8yZLzCQ
#   lon       lat
# 1 -88.75036 41.92947
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Egyptian+Theatre+in+DeKalb,+Illinois&key=xxx-dR-wCtEsgGsLLjRM-PeQhnbU8yZLzCQ
#   lon       lat
# 1 -88.75257 41.93093

# %% [markdown]
# <span style="color:red">22. Use `ggmap` to create a actual map stored in variable but calling `get_map` within the ggmap for *Egyptian Theatre in DeKalb, Illinois*.</span>

# %%
dekalb_map <- get_map(dekalbtheatre)
ggmap(dekalb_map,zoom=18)
# Out:
# Source : https://maps.googleapis.com/maps/api/staticmap?center=41.930927,-88.752573&zoom=10&size=640x640&scale=2&maptype=terrain&language=en-EN&key=xxx-dR-wCtEsgGsLLjRM-PeQhnbU8yZLzCQ
# plot without title

# %% [markdown]
# <span style="color:red">23. Create a map using `ggmap` for *DeKalb, IL*, with a zoom factor of 15 and a maptype of *toner-lite*. On that map place a red dot to mark the *Egyptian Theater*.</span>

# %%
map1 <- geocode("DeKalb, IL")
ggmap(get_map(map1,zoom=15,maptype="toner-lite")) +
geom_point(mapping=aes(x=lon,y=lat),color="red",data=dekalbtheatre)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=DeKalb,+IL&key=xxx-dR-wCtEsgGsLLjRM-PeQhnbU8yZLzCQ
# maptype = "toner-lite" is only available with source = "stamen".
# resetting to source = "stamen"...
# Source : https://maps.googleapis.com/maps/api/staticmap?center=41.929474,-88.750365&zoom=15&size=640x640&scale=2&maptype=terrain&key=xxx-dR-wCtEsgGsLLjRM-PeQhnbU8yZLzCQ
# plot without title
