# %% [markdown]
# # Assignment02 - Python and Plotting
#
# This assignment will explore the plotting capabilites of python. It will be using the following data:
# - `london-rain-clean.csv` from assignment01 (you will need to add it to the repository or read from your assignment01 directory)
# - `temperature.csv` included in repository
#
# It is assumed that you have removed any data with missing values in `london-rain-clean.csv` but that does not mean the data is free of errors.

# %% [markdown]
# - <span style="color:red">**Convert the following cell to markdown and write a few sentances about what could be other sources of error in the dataset.**</span>

# %% [markdown]
# The sources of error might be because of faulty instrument readings. Or the data might be corrupted while transmission.

# %% [markdown]
# - <span style="color:red">**Write the required python code to load the `london-rain-clean.csv` data.**</span>

# %%
import pandas as pd 
pd.read_csv("london-rain-clean.csv")
# Out:
#                   date site variable  value units type
# 0     01/01/2017 00:15  BG1     RAIN    0.0    mm    P
# 1     01/01/2017 00:30  BG1     RAIN    0.0    mm    P
# 2     01/01/2017 00:45  BG1     RAIN    0.0    mm    P
# 3     01/01/2017 01:00  BG1     RAIN    0.0    mm    P
# 4     01/01/2017 01:15  BG1     RAIN    0.0    mm    P
# 5     01/01/2017 01:30  BG1     RAIN    0.0    mm    P
# 6     01/01/2017 01:45  BG1     RAIN    0.0    mm    P
# 7     01/01/2017 02:00  BG1     RAIN    0.0    mm    P
# 8     01/01/2017 02:15  BG1     RAIN    0.0    mm    P
# 9     01/01/2017 02:30  BG1     RAIN    0.0    mm    P
# 10    01/01/2017 02:45  BG1     RAIN    0.0    mm    P
# 11    01/01/2017 03:00  BG1     RAIN    0.0    mm    P
# 12    01/01/2017 03:15  BG1     RAIN    0.0    mm    P
# 13    01/01/2017 03:30  BG1     RAIN    0.0    mm    P
# 14    01/01/2017 03:45  BG1     RAIN    0.0    mm    P
# 15    01/01/2017 04:00  BG1     RAIN    0.0    mm    P
# 16    01/01/2017 04:15  BG1     RAIN    0.0    mm    P
# 17    01/01/2017 04:30  BG1     RAIN    0.0    mm    P
# 18    01/01/2017 04:45  BG1     RAIN    0.0    mm    P
# 19    01/01/2017 05:00  BG1     RAIN    0.0    mm    P
# 20    01/01/2017 05:15  BG1     RAIN    0.0    mm    P
# 21    01/01/2017 05:30  BG1     RAIN    0.0    mm    P
# 22    01/01/2017 05:45  BG1     RAIN    0.0    mm    P
# 23    01/01/2017 06:00  BG1     RAIN    0.0    mm    P
# 24    01/01/2017 06:15  BG1     RAIN    0.0    mm    P
# 25    01/01/2017 06:30  BG1     RAIN    0.0    mm    P
# 26    01/01/2017 06:45  BG1     RAIN    0.0    mm    P
# 27    01/01/2017 07:00  BG1     RAIN    0.0    mm    P
# 28    01/01/2017 07:15  BG1     RAIN    0.0    mm    P
# 29    01/01/2017 07:30  BG1     RAIN    0.0    mm    P
# ...                ...  ...      ...    ...   ...  ...
# 5921  31/01/2017 16:30  BQ7     RAIN    0.0    mm    P
# 5922  31/01/2017 16:45  BQ7     RAIN    0.0    mm    P
# 5923  31/01/2017 17:00  BQ7     RAIN    0.0    mm    P
# 5924  31/01/2017 17:15  BQ7     RAIN    0.0    mm    P
# 5925  31/01/2017 17:30  BQ7     RAIN    0.0    mm    P
# 5926  31/01/2017 17:45  BQ7     RAIN    0.0    mm    P
# 5927  31/01/2017 18:00  BQ7     RAIN    0.0    mm    P
# 5928  31/01/2017 18:15  BQ7     RAIN    0.0    mm    P
# 5929  31/01/2017 18:30  BQ7     RAIN    0.0    mm    P
# 5930  31/01/2017 18:45  BQ7     RAIN    0.0    mm    P
# 5931  31/01/2017 19:00  BQ7     RAIN    0.0    mm    P
# 5932  31/01/2017 19:15  BQ7     RAIN    0.0    mm    P
# 5933  31/01/2017 19:30  BQ7     RAIN    0.0    mm    P
# 5934  31/01/2017 19:45  BQ7     RAIN    0.0    mm    P
# 5935  31/01/2017 20:00  BQ7     RAIN    2.0    mm    P
# 5936  31/01/2017 20:15  BQ7     RAIN    2.0    mm    P
# 5937  31/01/2017 20:30  BQ7     RAIN    2.0    mm    P
# 5938  31/01/2017 20:45  BQ7     RAIN    2.0    mm    P
# 5939  31/01/2017 21:00  BQ7     RAIN    8.0    mm    P
# 5940  31/01/2017 21:15  BQ7     RAIN    8.0    mm    P
# 5941  31/01/2017 21:30  BQ7     RAIN    8.0    mm    P
# 5942  31/01/2017 21:45  BQ7     RAIN    8.0    mm    P
# 5943  31/01/2017 22:00  BQ7     RAIN    4.0    mm    P
# 5944  31/01/2017 22:15  BQ7     RAIN    4.0    mm    P
# 5945  31/01/2017 22:30  BQ7     RAIN    4.0    mm    P
# 5946  31/01/2017 22:45  BQ7     RAIN    4.0    mm    P
# 5947  31/01/2017 23:00  BQ7     RAIN    2.0    mm    P
# 5948  31/01/2017 23:15  BQ7     RAIN    2.0    mm    P
# 5949  31/01/2017 23:30  BQ7     RAIN    2.0    mm    P
# 5950  31/01/2017 23:45  BQ7     RAIN    2.0    mm    P
#
# [5951 rows x 6 columns]

# %% [markdown]
# - <span style="color:red">**Write the required python code to produce a simple plot, this should be one line of python code in your jupyter cell, plus some magic.**</span>

# %%
import matplotlib.pyplot as plt
df = pd.read_csv("london-rain-clean.csv")
df.plot()
plt.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# - <span style="color:red">**Write a short summary of what you see and what initial thoughts you have about the data. (You will need to convert the cell below to a markdown cell)**</span>

# %% [markdown]
# By looking at the graph we can get to know that at what day how much mm did it rained. And using the graph we can identify this easily than to looks at nodes.

# %% [markdown]
# Detection of outliers is an art and there is no set standard method as it is very data dependent.  For the purpose of this assignment, you will be looking at rainfall data and you bring a basic understanding of how rain works, what is reasonable and what is not. We will use 2 standard deviations from the mean as our first filter point.

# %% [markdown]
# - <span style="color:red">**Write the required python code to calculate the mean and standard deviation for the *value* variable from the rain dataset.**</span>

# %%
df.loc[:,"value"].mean()
# Out:
# 1.6703093476798925

# %%
df.loc[:,"value"].std()
# Out:
# 41.0348612934262

# %% [markdown]
# - <span style="color:red">**Write the required python code to calculate the lower and upper bounds of values that is 2 standard deviations from the mean.**</span>
#
# $$ lower = rainMean - (2 * rainStd) $$
# $$ upper = rainMean + (2 * rainStd) $$

# %%
rainMean = df.loc[:,"value"].mean()
rainStd = df.loc[:,"value"].std()
lower = rainMean-(2*rainStd)
upper = rainMean+(2*rainStd)
lower
# Out:
# -80.3994132391725

# %%
upper
# Out:
# 83.74003193453228

# %% [markdown]
# - <span style="color:red">**Write the required python code to plot rain values with data filtered out using your lower and upper bounds.**</span>

# %%
df1 = df[(df['value']>lower)&(df['value']<upper)]
df['value'] = df1['value']
plt.plot(df.index,df.value)

# %% [markdown]
# - <span style="color:red">**Write a short summary of what you see and your revised thoughts about the data. Does the data seem more reasonable now that you have filtered the data? (You will need to convert the cell below to a markdown cell)**</span>

# %% [markdown]
# No still the data doesnt seem to be reasomable as we are getting negative values again and rainfall cannot br negative.

# %% [markdown]
# - <span style="color:red">**Modify your python code to increase the size of your figure to (20,10).**</span>

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.plot(df.index,df.value)

# %% [markdown]
# - <span style="color:red">**If the larger graph helps you see anything new in your data, write a short summary (you will need to convert the cell below to a markdown cell), if not leave the cell blank.**</span>

# %% [markdown]
# - <span style="color:red">**If you are happy with your visualization, then we can move on, if not modify your code one last time to fix any other concerns you may have in terms of data values captured in the visualization that should not be there.**</span>

# %%
df1 = df[(df['value']>=0)&(df['value']<upper)]
df['value'] = df1['value']
plt.plot(df.index,df.value)

# %% [markdown]
# Please note, this is **not a final visualization** of the London rain data, there are numerous things still wrong with the graph if you followed the directions, the graph will be missing title, labels and even the bars are somewhat misleading. This assignment was intended to introduce you to the use of graphing in debugging/cleaning of your data.
#
# We will now switch to a clean dataset for rest of the lesson.  You do not need to worry about data quality here, this portion of the assigment will focus on ensuring you understand how to code for additional required components in a final visualization.

# %% [markdown]
# - <span style="color:red">**Write the needed python code to load the `temperature.csv` file into a pandas dataframe.**</span>

# %%
import pandas as pd1
pd1.read_csv("temperature.csv")
df3 = pd1.read_csv("temperature.csv")
df3.set_index(pd1.to_datetime(df3['date'], format='%Y-%m-%d %H:%M:%S.%f'), inplace=True)
df3 = df3.drop(['date'], axis=1)
df3
# Out:
#                            nodeid  temperature
# date
# 2018-07-15 05:00:02  001e0610b9e9        32.10
# 2018-07-15 05:00:02  001e0610e537        27.10
# 2018-07-15 05:00:03  001e0610ee61        26.70
# 2018-07-15 05:00:03  001e061135cb        25.40
# 2018-07-15 05:00:03  001e06113f54        53.20
# 2018-07-15 05:00:03  001e06115365        60.60
# 2018-07-15 05:00:04  001e061144be        52.80
# 2018-07-15 05:00:05  001e0610ee41        26.25
# 2018-07-15 05:00:05  001e0610ee43        24.80
# 2018-07-15 05:00:06  001e0610bc12        57.80
# 2018-07-15 05:00:06  001e0610e532        28.05
# 2018-07-15 05:00:07  001e0610f05c        26.20
# 2018-07-15 05:00:08  001e06113cf1        57.50
# 2018-07-15 05:00:08  001e061146cb        52.60
# 2018-07-15 05:00:09  001e06109416        46.20
# 2018-07-15 05:00:09  001e061130f4        26.20
# 2018-07-15 05:00:09  001e061144c0        54.30
# 2018-07-15 05:00:10  001e0610eef2        59.10
# 2018-07-15 05:00:10  001e06113ad8        56.10
# 2018-07-15 05:00:10  001e0611462f        49.30
# 2018-07-15 05:00:11  001e0610e835        50.80
# 2018-07-15 05:00:11  001e06113a48        43.50
# 2018-07-15 05:00:12  001e0610bbff        26.90
# 2018-07-15 05:00:12  001e0610e809        28.05
# 2018-07-15 05:00:13  001e0610e540        31.00
# 2018-07-15 05:00:13  001e0610ef27        26.20
# 2018-07-15 05:00:14  001e0610f730        27.65
# 2018-07-15 05:00:14  001e06113acb        52.80
# 2018-07-15 05:00:15  001e0611537d        49.60
# 2018-07-15 05:00:16  001e0610ee36        31.60
# ...                           ...          ...
# 2018-07-21 04:59:43  001e06113a48        39.00
# 2018-07-21 04:59:44  001e06115365        55.40
# 2018-07-21 04:59:45  001e06113cf1        53.60
# 2018-07-21 04:59:47  001e0610b9e9        30.10
# 2018-07-21 04:59:47  001e0610e835        48.20
# 2018-07-21 04:59:47  001e061146d6        45.90
# 2018-07-21 04:59:47  001e0611537d        44.90
# 2018-07-21 04:59:48  001e0610e540        25.40
# 2018-07-21 04:59:48  001e061135cb        21.45
# 2018-07-21 04:59:49  001e0610bbff        22.69
# 2018-07-21 04:59:49  001e0610ee82        22.20
# 2018-07-21 04:59:49  001e0610f05c        23.50
# 2018-07-21 04:59:50  001e06109f62        45.40
# 2018-07-21 04:59:51  001e0610e532        23.40
# 2018-07-21 04:59:51  001e0610e537        24.90
# 2018-07-21 04:59:51  001e06113cff        53.20
# 2018-07-21 04:59:51  001e06113d22        46.30
# 2018-07-21 04:59:52  001e0610bbf9        16.10
# 2018-07-21 04:59:52  001e061144c0        48.70
# 2018-07-21 04:59:54  001e0610ba46        22.20
# 2018-07-21 04:59:55  001e0610f730        23.55
# 2018-07-21 04:59:56  001e0610ef27        23.20
# 2018-07-21 04:59:57  001e0610ee5d        26.90
# 2018-07-21 04:59:57  001e06113f54        52.10
# 2018-07-21 04:59:58  001e0610bc12        53.30
# 2018-07-21 04:59:59  001e0610ee36        24.40
# 2018-07-21 04:59:59  001e0610eef4        24.20
# 2018-07-21 04:59:59  001e061130f4        20.80
# 2018-07-21 04:59:59  001e0611536c        44.50
# 2018-07-21 05:00:00  001e0610ef73        28.70
#
# [940312 rows x 2 columns]

# %% [markdown]
# - <span style="color:red">**Write the needed python code to plot the temperature of the dataframe. You should be able to do this in a single line of python code.**</span>

# %%
df3 = pd1.read_csv("temperature.csv")
df3.plot()

# %% [markdown]
# - <span style="color:red">**Convert the following cell to markdown and describe what you see and any issues you have with this initial visualization.**</span>

# %% [markdown]
# We see a graph of the temperature fluctuations according to the days. The issue i find is that the graph does not clearly represent the data, it is difficult to get the accurate temperature at a particular point of time.

# %% [markdown]
# - <span style="color:red">**Write the needed python code to plot the temperature values of a single node from the dataframe. You should be able to do this in a single line of python code.**</span>

# %%
singledf = df3[df3.nodeid == "001e06113cf1"]
singledf.resample('60Min').mean().head()
plt.plot(singledf.index, singledf.temperature)

# %% [markdown]
# - <span style="color:red">**Convert the following cell to markdown and describe what new insight you have gained about the `temperature.csv` dataset.**</span>

# %% [markdown]
# Here, the data representation to be concise, we can get the temperature at each and time more accurately.

# %% [markdown]
# - <span style="color:red">**You are now assigned the task of producing a single visualization of a node from the temperature.csv dataset, write the needed python code to produce a visualization that is (20, 10) in size, you only need to worry about producing the visualization in the next cell, addtional components such as title and labels will follow in future questions.**</span> (Hint: This will require more code than past plots and you need to think about the final visualization in terms of what is useful to your viewer in understanding the data. Again don't worry about titles and labels at this point.)

# %% [markdown]
# - <span style="color:red">**Write the needed python code to add the following title "Temperature Values for Node &lt;node used in visualization&gt;" to your previous plot.**</span>

# %%
plt.title("Temperature Values for Node 001e06113cf1")
plt.plot(singledf.index, singledf.temperature)

# %% [markdown]
# - <span style="color:red">**Write the needed python code to add the following labels "Temperature (C)" to your y-axis and the appropriate label to your x-axis code from previous plot.**</span>

# %%
plt.title("Temperature Values for Node 001e06113cf1")
plt.xlabel("Time")
plt.ylabel("Temperature(c)")
plt.plot(singledf.index, singledf.temperature)

# %% [markdown]
# - <span style="color:red">**The plot should nearly be complete now, using the code from your previous plot, write the needed python code to remove the legend.**</span>

# %%
df3.plot(legend=False)

# %% [markdown]
# - <span style="color:red">**Using your code from your final plot above, add the needed python code to save the final visualization to a PNG file with the filename "FinalVis".**</span>

# %%
plt.title("Temperature Values for Node 001e06113cf1")
plt.xlabel("Time")
plt.ylabel("Temperature(c)")
plt.plot(singledf.index, singledf.temperature)
plt.savefig('FinalVis.png')

# %% [markdown]
# - <span style="color:red">**BONUS QUESTION: Write the required python code to display the temperature value for all the nodes on a single plot. Hint: Use the alpha component to make lines semi-transparent to help with readability (alpha=0.05)**</span>
